# %% [markdown]
# # HLD and Centroid Decomposition
#
# ## 1. Heavy-Light Decomposition (HLD)
# HLD is a technique used to decompose a tree into paths for efficient queries.
#
# ## 2. Centroid Decomposition
# Divide and conquer on trees.
