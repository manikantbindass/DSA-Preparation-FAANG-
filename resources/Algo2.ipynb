# %% [markdown]
# # 🚀 Data Structures & Algorithms (DSA) - Complete Guide
#
# ## 📌 Goal
# This notebook covers:
# - Basics to Advanced
# - Layman explanations
# - Step-by-step breakdowns
# - Code implementations
#
# ---
#
# ## 🧠 What is DSA?
#
# **Layman Terms:**
# Think of DSA like organizing your room.
# - Data Structure = How you store things (shelves, boxes)
# - Algorithm = Steps to find something quickly
#
# ---

# %% [markdown]
# # 📦 1. Arrays (Basics)
#
# ## 🧠 Layman Explanation
# Array is like a row of lockers.
# Each locker has an index.
#
# ## ⚙️ Operations
# - Access
# - Insert
# - Delete

# %%
# Array Example
arr = [10, 20, 30, 40]

# Access
print(arr[2])  # 30

# Insert
arr.append(50)

# Delete
arr.remove(20)

print(arr)

# %% [markdown]
# # ⏱ Time Complexity
#
# - Access → O(1)
# - Insert/Delete → O(n)
#
# **Layman:**
# Finding a locker is instant, but shifting items takes time.

# %% [markdown]
# # 🔍 2. Searching Algorithms
#
# ## Linear Search
#
# **Layman:**
# Check every item one by one.

# %%
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

print(linear_search([1,2,3,4], 3))

# %% [markdown]
# ## Binary Search
#
# **Layman:**
# Like searching in a dictionary — divide in half.

# %%
def binary_search(arr, target):
    left, right = 0, len(arr)-1

    while left <= right:
        mid = (left + right)//2

        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return -1

print(binary_search([1,2,3,4,5], 4))

# %% [markdown]
# # 🌳 3. Recursion
#
# **Layman:**
# Function calling itself.
#
# Example: Factorial

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n-1)

print(factorial(5))

# %% [markdown]
# # 📚 4. Sorting Algorithms
#
# ## Bubble Sort
#
# **Layman:**
# Swap neighbors until sorted.

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

print(bubble_sort([5,3,1,4]))

# %% [markdown]
# # 🌲 5. Trees
#
# **Layman:**
# Like a family tree.
#
# - Root
# - Children
# - Leaf

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

root = Node(1)
root.left = Node(2)
root.right = Node(3)

print(root.left.val)

# %% [markdown]
# # 🌐 6. Graphs
#
# **Layman:**
# Cities connected by roads.

# %%
graph = {
    0: [1,2],
    1: [0,3],
    2: [0],
    3: [1]
}

def dfs(node, visited):
    if node in visited:
        return
    print(node)
    visited.add(node)

    for nei in graph[node]:
        dfs(nei, visited)

dfs(0, set())

# %% [markdown]
# # ⚡ 7. Dynamic Programming (Advanced)
#
# **Layman:**
# Solve once, reuse later.
#
# Example: Fibonacci

# %%
def fib(n, dp={}):
    if n in dp:
        return dp[n]
    if n <= 1:
        return n

    dp[n] = fib(n-1, dp) + fib(n-2, dp)
    return dp[n]

print(fib(10))

# %% [markdown]
# # 🏁 Conclusion
#
# ## 🎯 What You Learned
# - Arrays
# - Searching
# - Recursion
# - Sorting
# - Trees
# - Graphs
# - Dynamic Programming
#
# ---
#
# ## 🚀 Next Steps
# - Solve LeetCode problems
# - Optimize time complexity
# - Practice daily
