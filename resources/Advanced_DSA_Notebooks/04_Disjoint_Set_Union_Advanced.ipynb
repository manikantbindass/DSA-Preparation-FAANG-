# %% [markdown]
# # Disjoint Set Union - Advanced Use
#
# DSU tracks groups. Advanced DSU also stores component size, parity, min/max, or other component data.
#
# This notebook explains the idea in plain language first, then gives Java and Python templates you can adapt in LeetCode and Codeforces.

# %% [markdown]
# ## When to use it
#
# Use it for dynamic connectivity, Kruskal, cycle detection, grouping swaps, and offline merging.
#
# ## Layman idea
#
# Every group has a leader. find gets the leader; union attaches smaller group under larger group.

# %% [markdown]
# ## Java implementation
#
# ```java
# class DSU {
#   int[] parent, size;
#   DSU(int n){ parent=new int[n]; size=new int[n]; for(int i=0;i<n;i++){parent[i]=i; size[i]=1;} }
#   int find(int x){ return parent[x]==x ? x : (parent[x]=find(parent[x])); }
#   boolean union(int a,int b){ int ra=find(a), rb=find(b); if(ra==rb) return false; if(size[ra]<size[rb]){int t=ra;ra=rb;rb=t;} parent[rb]=ra; size[ra]+=size[rb]; return true; }
#   int componentSize(int x){ return size[find(x)]; }
# }
# ```

# %% [markdown]
# ## Python implementation
#
# ```python
# class DSU:
#     def __init__(self, n): self.parent = list(range(n)); self.size = [1] * n
#     def find(self, x):
#         if self.parent[x] != x: self.parent[x] = self.find(self.parent[x])
#         return self.parent[x]
#     def union(self, a, b):
#         ra, rb = self.find(a), self.find(b)
#         if ra == rb: return False
#         if self.size[ra] < self.size[rb]: ra, rb = rb, ra
#         self.parent[rb] = ra; self.size[ra] += self.size[rb]; return True
#     def component_size(self, x): return self.size[self.find(x)]
# ```

# %%
class DSU:
    def __init__(self, n): self.parent = list(range(n)); self.size = [1] * n
    def find(self, x):
        if self.parent[x] != x: self.parent[x] = self.find(self.parent[x])
        return self.parent[x]
    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb: return False
        if self.size[ra] < self.size[rb]: ra, rb = rb, ra
        self.parent[rb] = ra; self.size[ra] += self.size[rb]; return True
    def component_size(self, x): return self.size[self.find(x)]

# %% [markdown]
# ## Complexity
#
# Almost O(1) per operation, formally O(alpha(n)).
#
# ## Common mistake
#
# After union, component data must live on the new root.
#
# ## Practice checklist
#
# - Identify the state or data structure invariant.
# - Write one tiny example by hand.
# - Check edge cases: empty input, one node/item, duplicate values, and disconnected graphs where relevant.
