# %% [markdown]
# # String Hashing
#
# String hashing is the general technique behind fast substring fingerprints.
#
# This notebook explains the idea in plain language first, then gives Java and Python templates you can adapt in LeetCode and Codeforces.

# %% [markdown]
# ## When to use it
#
# Use it for substring equality, palindrome checks, and binary-search-on-answer string problems.
#
# ## Layman idea
#
# Store prefix hashes and powers; subtract the shifted prefix to isolate a substring.

# %% [markdown]
# ## Java implementation
#
# ```java
# class RollingHash { long MOD=1_000_000_007L, BASE=911382323L; long[] h,p; RollingHash(String s){ int n=s.length(); h=new long[n+1]; p=new long[n+1]; p[0]=1; for(int i=0;i<n;i++){ h[i+1]=(h[i]*BASE+s.charAt(i))%MOD; p[i+1]=p[i]*BASE%MOD; } } long get(int l,int r){ long x=(h[r+1]-h[l]*p[r-l+1])%MOD; return x<0?x+MOD:x; } }
# ```

# %% [markdown]
# ## Python implementation
#
# ```python
# class RollingHash:
#     MOD=1_000_000_007; BASE=911_382_323
#     def __init__(self, s):
#         n=len(s); self.h=[0]*(n+1); self.p=[1]*(n+1)
#         for i,ch in enumerate(s): self.h[i+1]=(self.h[i]*self.BASE+ord(ch))%self.MOD; self.p[i+1]=self.p[i]*self.BASE%self.MOD
#     def get(self, l, r): return (self.h[r+1] - self.h[l] * self.p[r-l+1]) % self.MOD
# ```

# %%
class RollingHash:
    MOD=1_000_000_007; BASE=911_382_323
    def __init__(self, s):
        n=len(s); self.h=[0]*(n+1); self.p=[1]*(n+1)
        for i,ch in enumerate(s): self.h[i+1]=(self.h[i]*self.BASE+ord(ch))%self.MOD; self.p[i+1]=self.p[i]*self.BASE%self.MOD
    def get(self, l, r): return (self.h[r+1] - self.h[l] * self.p[r-l+1]) % self.MOD

# %% [markdown]
# ## Complexity
#
# Preprocess O(n), compare O(1), space O(n).
#
# ## Common mistake
#
# Use long in Java and avoid negative modulo bugs.
#
# ## Practice checklist
#
# - Identify the state or data structure invariant.
# - Write one tiny example by hand.
# - Check edge cases: empty input, one node/item, duplicate values, and disconnected graphs where relevant.
